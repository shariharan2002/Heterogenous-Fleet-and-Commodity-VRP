# %%
# Ram Ram

# %%
import networkx as nx
import random

# %%
commodities=['P1','P2','P3','P4']
total_nodes=['A','B','C','D','E','F','G']
depot_nodes=['A','B']
customer_nodes=['C','D','E','F','G']

vehicle_content=0
with open(r"C:\Users\Acer Pc\Desktop\VRP OpperHeimer\OpperHeimer Code\OpperHeimer Code\Data\vessel.txt") as f:
    vehicle_content=f.read()
vehicle_content=vehicle_content.split("\n")
if vehicle_content[-1] =='' or vehicle_content[-1] =='\n':
    vehicle_content=vehicle_content[:-1]
vehicle_dict={}
for item in vehicle_content:
    item=item.split(":")
    vehicle_cap=int(item[1].split(",")[0].split("(")[1].strip())
    vehicle_cost=int(item[1].split(",")[1].split(")")[0].strip())
    vehicle_dict[item[0].strip()]=[vehicle_cap,vehicle_cost]

capacity_content=0
with open(r"C:\Users\Acer Pc\Desktop\VRP OpperHeimer\OpperHeimer Code\OpperHeimer Code\Data\capacity.txt") as f:
    capacity_content=f.read()
capacity_content=capacity_content.split("\n")

if capacity_content[-1]==" " or capacity_content[-1]=="\n":
    capacity_content=capacity_content[:-1]

capacity_dict={}
for item in capacity_content:
    item=item.split(":")
    depot_id=item[0].split(",")[0].split("(")[1].strip()
    product_id=item[0].split(",")[1].split(")")[0].strip()
    depot_cap=int(item[1].strip())
    capacity_dict[(depot_id,product_id)]=depot_cap

time_content=0
with open(r"C:\Users\Acer Pc\Desktop\VRP OpperHeimer\OpperHeimer Code\OpperHeimer Code\Data\time.txt") as f:
    time_content=f.read()
time_content=time_content.split("\n")

if time_content[-1]==" " or time_content[-1]=="\n":
    time_content=time_content[:-1]
mapper={0:'A',1:'B',2:'C',3:'D',4:'E',5:'F',6:'G'}
time_dict={}
for item in time_content:
    item=item.split(":")
    source_depot=int(item[0].split(",")[0].split("(")[1].strip())
    destination_depot=int(item[0].split(",")[1].split(")")[0].strip())
    time_to_travel=int(item[1].strip())
    time_dict[(mapper[source_depot],mapper[destination_depot])]=time_to_travel
    time_dict[(mapper[destination_depot],mapper[source_depot])]=time_to_travel

# demand_content=0
# with open(r"C:\Users\Acer Pc\Desktop\VRP OpperHeimer\OpperHeimer Code\OpperHeimer Code\Data\demand.txt") as f:
#     demand_content=f.read()
# demand_content=demand_content.split("\n")

# if demand_content[-1]==" " or demand_content[-1]=="\n":
#     demand_content=demand_content[:-1]

with open(r"C:\Users\Acer Pc\Desktop\VRP OpperHeimer\OpperHeimer Code\OpperHeimer Code\Data\demand_by_day.txt","r") as f:
    x=f.read()

demand_content=x.split("\n")
demand_dict={}
for item in demand_content:
    if len(item)!=0:
        item=item.split(":")
        tup_list=item[0].strip().split(",")
        actual_node=tup_list[0].split("(")[1].strip().split("'")[1]
        actual_product=tup_list[1].strip().split("'")[1]
        actual_day=tup_list[2].split(")")[0].strip().split("'")[1]
        actual_demand=int(item[1].strip())
        demand_dict[(actual_node,actual_product,actual_day)]=actual_demand


days=[]
for i in range(1,16):
    days.append('D'+str(i))

# %%
# demand_low_param=10000
# demand_up_param=15000

# demand_dict={}

# for node in total_nodes:
#     for c in range(len(commodities)):
#         for d in range(len(days)):
#             if node in depot_nodes:
#                 demand_dict[(node,commodities[c],days[d])]=0
#             else:
#                 demand_dict[(node,commodities[c],days[d])]=random.randint(demand_low_param,demand_up_param)

# %%
G=nx.Graph()
for node in total_nodes:
    G.add_node(node)
for edge in time_dict.keys():
    if edge[0]!=edge[1]:
        G.add_edge(edge[0],edge[1],weight=time_dict[edge])

# %%
# from itertools import combinations,permutations

# global_paths_set=set()
# all_paths_list=[]
# roundtrips_dict={}

# for depot in depot_nodes:
#     roundtrips_dict[depot]=set()
#     for node in total_nodes:
#         for path in list(nx.all_simple_paths(G,depot,node)):
#             if depot not in path[1:]:
#                 temp=path.copy()
#                 temp.append(depot)
#                 temp=tuple(temp)
#                 roundtrips_dict[depot].add((temp))

# # for permutation in permutations(depot_nodes, 2):
# #     source_depot=permutation[0]
# #     destination_depot=permutation[1]
# #     for path in list(nx.all_simple_paths(G,source=source_depot,target=destination_depot)):
# #         temp=tuple(path)
# #         all_paths_list.append(path)
# #         global_paths_set.add(temp)

# for depot in depot_nodes:
#     for path in roundtrips_dict[depot]:
#         global_paths_set.add(path)


from itertools import combinations
current_set=total_nodes

tsp_paths={}
for k in range(1,len(current_set)):
    combinations_list=list(combinations(current_set,k))

    for node in depot_nodes:
        for item in combinations_list:
            temp=[]
            temp.append(node)
            for c_node in item:
                if c_node not in temp:
                    temp.append(c_node)
            if len(temp)>1:
                node_list=temp.copy()
                tsp=nx.approximation.traveling_salesman_problem
                path=tsp(G,nodes=node_list,weight='weight')
                tsp_paths[tuple(node_list)]=path.copy()

tsp_paths_reorg_list=[]
for key,value in tsp_paths.items():
    tsp_paths_reorg_list.append((key,value))

global_paths_set_mapper={}
global_paths_set=[]
for i in range(len(tsp_paths_reorg_list)):
    global_paths_set_mapper[i]=tsp_paths_reorg_list[i]
    global_paths_set.append(tsp_paths_reorg_list[i][1])
        
def get_in_order_customer_nodes(mapper):
    new_dict={}
    for keys,values in mapper.items():
        to_be_visited=values[0]
        path=values[1]
        in_order=[]
        for node in path:
            if node in to_be_visited and node not in in_order:
                in_order.append(node)
        new_dict[keys]=(tuple(in_order),path)
    return new_dict

global_paths_set_mapper=get_in_order_customer_nodes(global_paths_set_mapper)

# %%
# global_paths_set_copy=global_paths_set.copy()

# !!!!!!!!!!!!!!!!!!!! *************** WARNING WE HAVE CHANGED THE GLOBAL PATHS SET INTO A LIST FOR CONVENIENCE PURPOSES
# AS PYTHON WONT ALLOW SUBSCRIPTING A SET VIA POSITION INDEX

# global_paths_set=list(global_paths_set)

path_dict={}
for keys,values in vehicle_dict.items():
    for c in range(len(commodities)):
        for d in range(len(days)):
            path_dict[(keys,commodities[c],days[d])]={}
            for path_index in range(len(global_paths_set)):
                temp={'CustomerSet':[],'Start':-1,'End':-1,'DepotSet':[],'Path':[],'TotalCustomerDemand':0,'VehicleCapacity':0,'EachCustomerDemand':[],'Day':days[d],'Commodity':commodities[c],'VehicleType':keys,'MaxCustomerDemand':-1}

                #Setting start and end
                current_path=global_paths_set[path_index]
                deemed_to_visit=global_paths_set_mapper[path_index][0]
                temp['ActualVisited']=deemed_to_visit
                temp['Path']=current_path
                temp['Start']=current_path[0]
                temp['End']=current_path[-1]


                #Customer Sets and Depot Sets
                temp_customer_demand=0
                max_customer_demand=0
                for cur_node in deemed_to_visit:
                    if cur_node in customer_nodes:
                        if cur_node not in temp['CustomerSet']:
                            temp['CustomerSet'].append(cur_node)
                        temp_customer_demand+=(demand_dict[(cur_node,commodities[c],days[d])])
                        max_customer_demand=max(max_customer_demand,demand_dict[(cur_node,commodities[c],days[d])])
                    elif cur_node in depot_nodes:
                        if cur_node not in temp['DepotSet']:
                            temp['DepotSet'].append(cur_node)
                    temp['EachCustomerDemand'].append(demand_dict[(cur_node,commodities[c],days[d])])
                
                temp['TotalCustomerDemand']=temp_customer_demand
                temp['MaxCustomerDemand']=max_customer_demand
                temp['VehicleCapacity']=values[0]

                max_serving_capacity=0
                for d_node in temp['DepotSet']:
                    max_serving_capacity+=capacity_dict[(d_node,commodities[c])]
                if temp['VehicleCapacity'] >= temp['MaxCustomerDemand'] and max_serving_capacity>=temp['MaxCustomerDemand']:
                    temp['Feasible']= True
                else:
                    temp['Feasible']=False
                
                temp['Cost']=0
                for i in range(len(global_paths_set[path_index])-1):
                    temp['Cost']+=time_dict[(global_paths_set[path_index][i],global_paths_set[path_index][i+1])]*vehicle_dict[keys][1]
                
                temp['ConsumptionTracker']=0

                
                temp['CustomerSet']=list(temp['CustomerSet'])
                temp['DepotSet']=list(temp['DepotSet'])
                if temp['Feasible']==True:
                    #temp['ConsumptionTracker']=temp['TotalCustomerDemand']
                    path_dict[(keys,commodities[c],days[d])][path_index]=temp

# %%
feasible_path_dict={}
for keys,values_vehicle in vehicle_dict.items():
    for c in range(len(commodities)):
        for d in range(len(days)):
            feasible_path_dict[(keys,commodities[c],days[d])] = {}
            for path_index,values in path_dict[(keys,commodities[c],days[d])].items():
                temp=[]
                consumption_temp={}
                if len(path_dict[(keys,commodities[c],days[d])][path_index]['Path'])>=3:
                    supply_temp=0
                    # demand_temp=0
                    checker=True
                    cur_path=path_dict[(keys,commodities[c],days[d])][path_index]['Path']
                    just_now_visited=[]
                    for node_index in range(len(cur_path)):
                        if checker==True and cur_path[node_index] in path_dict[(keys,commodities[c],days[d])][path_index]['ActualVisited'] :
                            node=cur_path[node_index]
                            rem_demand=0
                            for rem_index in range(node_index+1, len(cur_path)):
                                new_visited_node=cur_path[rem_index]
                                if new_visited_node in customer_nodes and new_visited_node not in just_now_visited:
                                    rem_demand+=demand_dict[(new_visited_node,commodities[c],days[d])]

                            if node in depot_nodes and node_index!=0:
                                if supply_temp==values_vehicle[0]:
                                    #Vehicle FULL:
                                    consumption_temp[(keys,path_index,commodities[c],days[d],node_index)]=0
                                else:
                                    amt_consumed=0
                                    #Find difference
                                    difference=values_vehicle[0]-supply_temp
                                    if difference>0:
                                        if difference>capacity_dict[(node,commodities[c])]:
                                            supply_temp+=min(capacity_dict[(node,commodities[c])],max(rem_demand-supply_temp,0))
                                            amt_consumed=min(capacity_dict[(node,commodities[c])],max(rem_demand-supply_temp,0))
                                        elif difference<=capacity_dict[(node,commodities[c])]:
                                            supply_temp+=min(difference,max(rem_demand-supply_temp,0))
                                            amt_consumed=min(difference,max(rem_demand-supply_temp,0))
                                        # elif difference==capacity_dict[(node,commodities[c])]:
                                        #     supply_temp+=difference
                                        #     amt_consumed=difference
                                        consumption_temp[((keys,path_index,commodities[c],days[d],node_index))]=amt_consumed
                                    else:
                                        print("OMG!!! Somethign has seriosly gone wrong")

                                    
                            elif node in depot_nodes and node_index==0:

                            
                                
                                if values_vehicle[0]<=capacity_dict[(node,commodities[c])]:
                                    supply_temp+=min(values_vehicle[0],rem_demand)
                                    consumption_temp[(keys,path_index,commodities[c],days[d],node_index)]=min(values_vehicle[0],rem_demand)
                                else:
                                    supply_temp+=min(capacity_dict[(node,commodities[c])],rem_demand)
                                    consumption_temp[(keys,path_index,commodities[c],days[d],node_index)]=min(capacity_dict[(node,commodities[c])],rem_demand)

                            elif node in customer_nodes and node not in just_now_visited:
                                if supply_temp >= demand_dict[(node,commodities[c],days[d])]:
                                    supply_temp-=demand_dict[(node,commodities[c],days[d])]
                                    just_now_visited.append(node)
                                else:
                                    checker=False
                        else:
                            continue
                                
                    if checker==True:
                        feasible_path_dict[(keys,commodities[c],days[d])][path_index]=path_dict[(keys,commodities[c],days[d])][path_index]
                        feasible_path_dict[(keys,commodities[c],days[d])][path_index]['ConsumptionTracker']=consumption_temp
                        total_demand_to_be_served_by_path=0
                        for serve_node in feasible_path_dict[(keys,commodities[c],days[d])][path_index]['CustomerSet']:
                            total_demand_to_be_served_by_path+=demand_dict[(serve_node,commodities[c],days[d])]
                        feasible_path_dict[(keys,commodities[c],days[d])][path_index]['TotalDemandServed']=total_demand_to_be_served_by_path

# %%
feasible_vehicle_dict={}
for cust_node in customer_nodes:
    for c in range(len(commodities)):
        for d in range(len(days)):
            feasible_vehicle_dict[(cust_node,commodities[c],days[d])]=[]
            for vehicle_index,v1 in vehicle_dict.items():
                if demand_dict[(cust_node,commodities[c],days[d])]<=v1[0]:
                    feasible_vehicle_dict[(cust_node,commodities[c],days[d])].append(vehicle_index)

# %%
total_demand_to_be_satisfied=0
for cust_node in customer_nodes:
    for c in range(len(commodities)):
        for d in range(len(days)):
            total_demand_to_be_satisfied+=demand_dict[(cust_node,commodities[c],days[d])]

# %%
z_decision_variable_indices=[]
objective_function_values={}
for vehicle_index,v1 in vehicle_dict.items():
    for c in range(len(commodities)): 
        for d in range(len(days)):
            for path_index,v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                    z_decision_variable_indices.append((vehicle_index,path_index,commodities[c],days[d]))
                    objective_function_values[(vehicle_index,path_index,commodities[c],days[d])]= feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['Cost']-( (10**10) *feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['TotalDemandServed']) # + f
                    

from docplex.mp.model import Model

vrp_model = Model('Heterogenous Fleet MDMT-VRP')
z=vrp_model.binary_var_dict(z_decision_variable_indices,name='z')


obj_fn=0
for vehicle_index,v1 in vehicle_dict.items():
    for c in range(len(commodities)):
        for d in range(len(days)):
            for path_index,v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                obj_fn+=objective_function_values[(vehicle_index,path_index,commodities[c],days[d])]*z[(vehicle_index,path_index,commodities[c],days[d])]

obj_fn+=total_demand_to_be_satisfied * (10**10)


vrp_model.set_objective("min",obj_fn)

for j in customer_nodes:
    for c in range(len(commodities)):
        for d in range(len(days)):
            c_once=0
            for vehicle_index,v1 in vehicle_dict.items():
                if vehicle_index in feasible_vehicle_dict[(j,commodities[c],days[d])]:         
                    for path_index,v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                        if j in feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['CustomerSet']:
                            c_once+=z[(vehicle_index,path_index,commodities[c],days[d])]
                else:
                    continue
            if c_once:
                #print("BRO")
                vrp_model.add_constraint(c_once<=1,'cvo') #customer visit once(cvo)



for i in depot_nodes:
    for c in range(len(commodities)):
        depot_cap_constraint=0
        for vehicle_index,v1 in vehicle_dict.items():
            for d in range(len(days)):
                for path_index,v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                    for cons_key,cons_value in feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['ConsumptionTracker'].items():
                        if feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['Path'][cons_key[-1]] == i:
                            depot_cap_constraint+=(cons_value * z[(vehicle_index,path_index,commodities[c],days[d])])

                    # if feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['Start'] == i:
                    #     depot_cap_constraint+=(feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['ConsumptionTracker']*z[(vehicle_index,path_index,commodities[c],days[d])]) 
        if depot_cap_constraint:
            #print("HELLO",i,commodities[c])
            vrp_model.add_constraint(depot_cap_constraint <= capacity_dict[(i,commodities[c])], 'dcc') #depot capacity constraint(dcc)

# #------- --------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!

for i in depot_nodes:
    for vehicle_index, v1 in vehicle_dict.items():
        for c in range(len(commodities)):
            for d in range(len(days)):
                lhs=0
                for j in depot_nodes:
                    for path_index, v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                        if feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['Start']==i and feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['End']==j:
                            lhs+=z[(vehicle_index,path_index,commodities[c],days[d])]
                
                rhs=0
                for j in depot_nodes:
                    for path_index, v2 in feasible_path_dict[(vehicle_index,commodities[c],days[d])].items():
                        if feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['Start']==j and feasible_path_dict[(vehicle_index,commodities[c],days[d])][path_index]['End']==i:
                            rhs+=z[(vehicle_index,path_index,commodities[c],days[d])]

                #print("hhh",i,vehicle_index,commodities)
                vrp_model.add_constraint(lhs==rhs, 'dbc') #depot balance constraint(dbc)
            


sol=vrp_model.solve()


sol.get_objective_value()
# Out:
# 1.2187720001849948e+16

# %%
sol_values=sol.get_value_dict(z)
for k,v in sol_values.items():
    if v==1:
        print(True,k)
# Out:
# True ('V4', 11, 'P1', 'D1')
# True ('V4', 2, 'P1', 'D3')
# True ('V4', 11, 'P1', 'D3')
# True ('V4', 125, 'P1', 'D4')
# True ('V4', 53, 'P1', 'D5')
# True ('V4', 2, 'P1', 'D7')
# True ('V4', 19, 'P1', 'D8')
# True ('V4', 117, 'P1', 'D9')
# True ('V4', 109, 'P1', 'D12')
# True ('V4', 125, 'P1', 'D14')
# True ('V4', 96, 'P1', 'D15')
# True ('V4', 117, 'P2', 'D1')
# True ('V4', 125, 'P2', 'D2')
# True ('V4', 125, 'P2', 'D3')
# True ('V4', 125, 'P2', 'D4')
# True ('V4', 117, 'P2', 'D5')
# True ('V4', 125, 'P2', 'D6')
# True ('V4', 125, 'P2', 'D7')
# True ('V4', 125, 'P2', 'D8')
# True ('V4', 125, 'P2', 'D9')
# True ('V4', 125, 'P2', 'D10')
# True ('V4', 125, 'P2', 'D11')
# True ('V4', 125, 'P2', 'D12')
# True ('V4', 117, 'P2', 'D13')
# True ('V4', 117, 'P2', 'D14')
# True ('V4', 125, 'P2', 'D15')
# True ('V4', 117, 'P3', 'D1')
# True ('V4', 117, 'P3', 'D2')
# True ('V4', 117, 'P3', 'D3')
# True ('V4', 117, 'P3', 'D5')
# True ('V4', 117, 'P3', 'D6')
# True ('V4', 117, 'P3', 'D7')
# True ('V4', 117, 'P3', 'D8')
# True ('V4', 117, 'P3', 'D9')
# True ('V4', 117, 'P3', 'D11')
# True ('V4', 117, 'P3', 'D12')
# True ('V4', 117, 'P3', 'D13')
# True ('V4', 117, 'P3', 'D14')
# True ('V4', 123, 'P3', 'D15')
# True ('V4', 37, 'P4', 'D1')
# True ('V4', 4, 'P4', 'D4')
# True ('V4', 1, 'P4', 'D5')
# True ('V4', 77, 'P4', 'D6')
# True ('V4', 117, 'P4', 'D8')
# True ('V4', 84, 'P4', 'D9')
# True ('V4', 11, 'P4', 'D11')
# True ('V4', 19, 'P4', 'D11')

# %%
sol_values=sol.get_value_dict(z)
sol_paths=[]
print("-----> FINAL OBJECTIVE VALUE : ", sol.get_objective_value())
print("\n\n\n")
demand_satisfied_by_model=0
for k,v in sol_values.items():
    if v==1:
        print("**********************************************************")
        print("VESSEL TYPE   : ",k[0])
        print("ROUTE NO      : ",k[1])
        print("PRODUCT TYPE  : ",k[2])
        print("START REFINERY: ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['Start'])
        print("END REFINERY  : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['End'])
        print("ROUTE         : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['Path'])
        print("ROUTECOST     : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['Cost'])
        print("DAY           : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['Day'])
        print("CONSUMPTION   : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['ConsumptionTracker'])
        print("CUSTOMER SET  : ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['CustomerSet'])
        print("TOTALDEMANDSER: ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['TotalDemandServed'])
        print("EACHCUSTOMERDE: ",feasible_path_dict[(k[0],k[2],k[3])][k[1]]['EachCustomerDemand'])
        demand_satisfied_by_model+=feasible_path_dict[(k[0],k[2],k[3])][k[1]]['TotalDemandServed']
        sol_paths.append((k,feasible_path_dict[(k[0],k[2],k[3])][k[1]]))
        print("**********************************************************\n\n")
# Out:
# -----> FINAL OBJECTIVE VALUE :  1.2187720001849948e+16
#
#
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  11
# PRODUCT TYPE  :  P1
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'G', 'B']
# ROUTECOST     :  22500
# DAY           :  D1
# CONSUMPTION   :  {('V4', 11, 'P1', 'D1', 0): 13497, ('V4', 11, 'P1', 'D1', 2): 0}
# CUSTOMER SET  :  ['G']
# TOTALDEMANDSER:  13497
# EACHCUSTOMERDE:  [0, 13497]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  2
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'D', 'A']
# ROUTECOST     :  25200
# DAY           :  D3
# CONSUMPTION   :  {('V4', 2, 'P1', 'D3', 0): 10227, ('V4', 2, 'P1', 'D3', 2): 0}
# CUSTOMER SET  :  ['D']
# TOTALDEMANDSER:  10227
# EACHCUSTOMERDE:  [0, 10227]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  11
# PRODUCT TYPE  :  P1
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'G', 'B']
# ROUTECOST     :  22500
# DAY           :  D3
# CONSUMPTION   :  {('V4', 11, 'P1', 'D3', 0): 13443, ('V4', 11, 'P1', 'D3', 2): 0}
# CUSTOMER SET  :  ['G']
# TOTALDEMANDSER:  13443
# EACHCUSTOMERDE:  [0, 13443]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P1
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D4
# CONSUMPTION   :  {('V4', 125, 'P1', 'D4', 0): 66717, ('V4', 125, 'P1', 'D4', 1): 0, ('V4', 125, 'P1', 'D4', 7): 0, ('V4', 125, 'P1', 'D4', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66717
# EACHCUSTOMERDE:  [0, 0, 13143, 14421, 13867, 11769, 13517]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  53
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'D', 'C', 'F', 'A']
# ROUTECOST     :  29250
# DAY           :  D5
# CONSUMPTION   :  {('V4', 53, 'P1', 'D5', 0): 34283, ('V4', 53, 'P1', 'D5', 4): 0}
# CUSTOMER SET  :  ['D', 'C', 'F']
# TOTALDEMANDSER:  34283
# EACHCUSTOMERDE:  [0, 11289, 12793, 10201]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  2
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'D', 'A']
# ROUTECOST     :  25200
# DAY           :  D7
# CONSUMPTION   :  {('V4', 2, 'P1', 'D7', 0): 13725, ('V4', 2, 'P1', 'D7', 2): 0}
# CUSTOMER SET  :  ['D']
# TOTALDEMANDSER:  13725
# EACHCUSTOMERDE:  [0, 13725]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  19
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'C', 'F', 'A']
# ROUTECOST     :  23850
# DAY           :  D8
# CONSUMPTION   :  {('V4', 19, 'P1', 'D8', 0): 27211, ('V4', 19, 'P1', 'D8', 3): 0}
# CUSTOMER SET  :  ['C', 'F']
# TOTALDEMANDSER:  27211
# EACHCUSTOMERDE:  [0, 14067, 13144]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D9
# CONSUMPTION   :  {('V4', 117, 'P1', 'D9', 0): 63614, ('V4', 117, 'P1', 'D9', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  63614
# EACHCUSTOMERDE:  [0, 14884, 14219, 11280, 11126, 12105]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  109
# PRODUCT TYPE  :  P1
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'D', 'C', 'F', 'G', 'B']
# ROUTECOST     :  40950
# DAY           :  D12
# CONSUMPTION   :  {('V4', 109, 'P1', 'D12', 0): 50072, ('V4', 109, 'P1', 'D12', 5): 0}
# CUSTOMER SET  :  ['D', 'C', 'F', 'G']
# TOTALDEMANDSER:  50072
# EACHCUSTOMERDE:  [0, 13459, 12371, 13736, 10506]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P1
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D14
# CONSUMPTION   :  {('V4', 125, 'P1', 'D14', 0): 61271, ('V4', 125, 'P1', 'D14', 1): 0, ('V4', 125, 'P1', 'D14', 7): 0, ('V4', 125, 'P1', 'D14', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  61271
# EACHCUSTOMERDE:  [0, 0, 11831, 11102, 14804, 10218, 13316]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  96
# PRODUCT TYPE  :  P1
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'D', 'E', 'G', 'F', 'A']
# ROUTECOST     :  34650
# DAY           :  D15
# CONSUMPTION   :  {('V4', 96, 'P1', 'D15', 0): 50939, ('V4', 96, 'P1', 'D15', 5): 0}
# CUSTOMER SET  :  ['D', 'E', 'G', 'F']
# TOTALDEMANDSER:  50939
# EACHCUSTOMERDE:  [0, 13133, 10940, 12979, 13887]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P2
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D1
# CONSUMPTION   :  {('V4', 117, 'P2', 'D1', 0): 59799, ('V4', 117, 'P2', 'D1', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  59799
# EACHCUSTOMERDE:  [0, 10088, 14624, 10281, 10487, 14319]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D2
# CONSUMPTION   :  {('V4', 125, 'P2', 'D2', 0): 0, ('V4', 125, 'P2', 'D2', 1): 0, ('V4', 125, 'P2', 'D2', 7): 0, ('V4', 125, 'P2', 'D2', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  65146
# EACHCUSTOMERDE:  [0, 0, 12607, 12373, 14243, 10938, 14985]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D3
# CONSUMPTION   :  {('V4', 125, 'P2', 'D3', 0): 0, ('V4', 125, 'P2', 'D3', 1): 0, ('V4', 125, 'P2', 'D3', 7): 0, ('V4', 125, 'P2', 'D3', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66715
# EACHCUSTOMERDE:  [0, 0, 12791, 14604, 13846, 14012, 11462]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D4
# CONSUMPTION   :  {('V4', 125, 'P2', 'D4', 0): 0, ('V4', 125, 'P2', 'D4', 1): 0, ('V4', 125, 'P2', 'D4', 7): 0, ('V4', 125, 'P2', 'D4', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66721
# EACHCUSTOMERDE:  [0, 0, 14375, 14078, 11843, 11502, 14923]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P2
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D5
# CONSUMPTION   :  {('V4', 117, 'P2', 'D5', 0): 54540, ('V4', 117, 'P2', 'D5', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  54540
# EACHCUSTOMERDE:  [0, 10424, 10863, 10553, 12322, 10378]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D6
# CONSUMPTION   :  {('V4', 125, 'P2', 'D6', 0): 0, ('V4', 125, 'P2', 'D6', 1): 0, ('V4', 125, 'P2', 'D6', 7): 0, ('V4', 125, 'P2', 'D6', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  59582
# EACHCUSTOMERDE:  [0, 0, 11821, 11954, 11923, 12359, 11525]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D7
# CONSUMPTION   :  {('V4', 125, 'P2', 'D7', 0): 0, ('V4', 125, 'P2', 'D7', 1): 0, ('V4', 125, 'P2', 'D7', 7): 0, ('V4', 125, 'P2', 'D7', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  71504
# EACHCUSTOMERDE:  [0, 0, 12817, 14994, 14820, 14982, 13891]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D8
# CONSUMPTION   :  {('V4', 125, 'P2', 'D8', 0): 0, ('V4', 125, 'P2', 'D8', 1): 0, ('V4', 125, 'P2', 'D8', 7): 0, ('V4', 125, 'P2', 'D8', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  58615
# EACHCUSTOMERDE:  [0, 0, 10616, 13442, 12037, 12143, 10377]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D9
# CONSUMPTION   :  {('V4', 125, 'P2', 'D9', 0): 0, ('V4', 125, 'P2', 'D9', 1): 0, ('V4', 125, 'P2', 'D9', 7): 0, ('V4', 125, 'P2', 'D9', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  65993
# EACHCUSTOMERDE:  [0, 0, 14753, 11972, 14803, 12011, 12454]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D10
# CONSUMPTION   :  {('V4', 125, 'P2', 'D10', 0): 0, ('V4', 125, 'P2', 'D10', 1): 0, ('V4', 125, 'P2', 'D10', 7): 0, ('V4', 125, 'P2', 'D10', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  63213
# EACHCUSTOMERDE:  [0, 0, 14877, 14023, 12584, 10231, 11498]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D11
# CONSUMPTION   :  {('V4', 125, 'P2', 'D11', 0): 0, ('V4', 125, 'P2', 'D11', 1): 0, ('V4', 125, 'P2', 'D11', 7): 0, ('V4', 125, 'P2', 'D11', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  67420
# EACHCUSTOMERDE:  [0, 0, 14880, 12665, 11896, 14115, 13864]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D12
# CONSUMPTION   :  {('V4', 125, 'P2', 'D12', 0): 0, ('V4', 125, 'P2', 'D12', 1): 0, ('V4', 125, 'P2', 'D12', 7): 0, ('V4', 125, 'P2', 'D12', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  61946
# EACHCUSTOMERDE:  [0, 0, 11308, 11071, 14012, 10902, 14653]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P2
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D13
# CONSUMPTION   :  {('V4', 117, 'P2', 'D13', 0): 56151, ('V4', 117, 'P2', 'D13', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  56151
# EACHCUSTOMERDE:  [0, 10031, 11041, 10061, 10364, 14654]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P2
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D14
# CONSUMPTION   :  {('V4', 117, 'P2', 'D14', 0): 58191, ('V4', 117, 'P2', 'D14', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  58191
# EACHCUSTOMERDE:  [0, 14483, 11167, 10081, 11586, 10874]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  125
# PRODUCT TYPE  :  P2
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'A', 'F', 'G', 'E', 'D', 'C', 'A', 'B']
# ROUTECOST     :  49950
# DAY           :  D15
# CONSUMPTION   :  {('V4', 125, 'P2', 'D15', 0): 0, ('V4', 125, 'P2', 'D15', 1): 0, ('V4', 125, 'P2', 'D15', 7): 0, ('V4', 125, 'P2', 'D15', 8): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  64515
# EACHCUSTOMERDE:  [0, 0, 11648, 14111, 12877, 14322, 11557]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D1
# CONSUMPTION   :  {('V4', 117, 'P3', 'D1', 0): 65692, ('V4', 117, 'P3', 'D1', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  65692
# EACHCUSTOMERDE:  [0, 13163, 12248, 14705, 14737, 10839]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D2
# CONSUMPTION   :  {('V4', 117, 'P3', 'D2', 0): 59646, ('V4', 117, 'P3', 'D2', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  59646
# EACHCUSTOMERDE:  [0, 14472, 10914, 11783, 11942, 10535]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D3
# CONSUMPTION   :  {('V4', 117, 'P3', 'D3', 0): 60545, ('V4', 117, 'P3', 'D3', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  60545
# EACHCUSTOMERDE:  [0, 10194, 10163, 13811, 14423, 11954]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D5
# CONSUMPTION   :  {('V4', 117, 'P3', 'D5', 0): 59183, ('V4', 117, 'P3', 'D5', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  59183
# EACHCUSTOMERDE:  [0, 12366, 11382, 11343, 12782, 11310]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D6
# CONSUMPTION   :  {('V4', 117, 'P3', 'D6', 0): 57745, ('V4', 117, 'P3', 'D6', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  57745
# EACHCUSTOMERDE:  [0, 13565, 11257, 10398, 10139, 12386]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D7
# CONSUMPTION   :  {('V4', 117, 'P3', 'D7', 0): 66878, ('V4', 117, 'P3', 'D7', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66878
# EACHCUSTOMERDE:  [0, 14479, 10323, 14990, 13844, 13242]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D8
# CONSUMPTION   :  {('V4', 117, 'P3', 'D8', 0): 66470, ('V4', 117, 'P3', 'D8', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66470
# EACHCUSTOMERDE:  [0, 14636, 10482, 14550, 14847, 11955]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D9
# CONSUMPTION   :  {('V4', 117, 'P3', 'D9', 0): 62409, ('V4', 117, 'P3', 'D9', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  62409
# EACHCUSTOMERDE:  [0, 12815, 13258, 11347, 14453, 10536]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D11
# CONSUMPTION   :  {('V4', 117, 'P3', 'D11', 0): 58168, ('V4', 117, 'P3', 'D11', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  58168
# EACHCUSTOMERDE:  [0, 12860, 10287, 13570, 10454, 10997]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D12
# CONSUMPTION   :  {('V4', 117, 'P3', 'D12', 0): 53464, ('V4', 117, 'P3', 'D12', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  53464
# EACHCUSTOMERDE:  [0, 11629, 10977, 10564, 10128, 10166]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D13
# CONSUMPTION   :  {('V4', 117, 'P3', 'D13', 0): 66409, ('V4', 117, 'P3', 'D13', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  66409
# EACHCUSTOMERDE:  [0, 13336, 14974, 14507, 10475, 13117]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P3
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D14
# CONSUMPTION   :  {('V4', 117, 'P3', 'D14', 0): 62488, ('V4', 117, 'P3', 'D14', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  62488
# EACHCUSTOMERDE:  [0, 13590, 12969, 13235, 11066, 11628]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  123
# PRODUCT TYPE  :  P3
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'G', 'F', 'C', 'D', 'E', 'G', 'B']
# ROUTECOST     :  47700
# DAY           :  D15
# CONSUMPTION   :  {('V4', 123, 'P3', 'D15', 0): 79643, ('V4', 123, 'P3', 'D15', 7): 0}
# CUSTOMER SET  :  ['G', 'F', 'C', 'D', 'E']
# TOTALDEMANDSER:  66904
# EACHCUSTOMERDE:  [0, 12739, 14986, 13272, 11170, 14737]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  37
# PRODUCT TYPE  :  P4
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'D', 'F', 'A', 'B']
# ROUTECOST     :  38700
# DAY           :  D1
# CONSUMPTION   :  {('V4', 37, 'P4', 'D1', 0): 24064, ('V4', 37, 'P4', 'D1', 4): 0}
# CUSTOMER SET  :  ['D', 'F']
# TOTALDEMANDSER:  24064
# EACHCUSTOMERDE:  [0, 10744, 13320]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  4
# PRODUCT TYPE  :  P4
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'A']
# ROUTECOST     :  13500
# DAY           :  D4
# CONSUMPTION   :  {('V4', 4, 'P4', 'D4', 0): 14304, ('V4', 4, 'P4', 'D4', 2): 0}
# CUSTOMER SET  :  ['F']
# TOTALDEMANDSER:  14304
# EACHCUSTOMERDE:  [0, 14304]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  1
# PRODUCT TYPE  :  P4
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'C', 'A']
# ROUTECOST     :  21600
# DAY           :  D5
# CONSUMPTION   :  {('V4', 1, 'P4', 'D5', 0): 13511, ('V4', 1, 'P4', 'D5', 2): 0}
# CUSTOMER SET  :  ['C']
# TOTALDEMANDSER:  13511
# EACHCUSTOMERDE:  [0, 13511]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  77
# PRODUCT TYPE  :  P4
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'C', 'F', 'G', 'B']
# ROUTECOST     :  37800
# DAY           :  D6
# CONSUMPTION   :  {('V4', 77, 'P4', 'D6', 0): 34539, ('V4', 77, 'P4', 'D6', 4): 0}
# CUSTOMER SET  :  ['C', 'F', 'G']
# TOTALDEMANDSER:  34539
# EACHCUSTOMERDE:  [0, 12858, 11552, 10129]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  117
# PRODUCT TYPE  :  P4
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'F', 'G', 'E', 'D', 'C', 'A']
# ROUTECOST     :  36450
# DAY           :  D8
# CONSUMPTION   :  {('V4', 117, 'P4', 'D8', 0): 65058, ('V4', 117, 'P4', 'D8', 6): 0}
# CUSTOMER SET  :  ['F', 'G', 'E', 'D', 'C']
# TOTALDEMANDSER:  65058
# EACHCUSTOMERDE:  [0, 10683, 14444, 14469, 13859, 11603]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  84
# PRODUCT TYPE  :  P4
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'C', 'D', 'G', 'B', 'A']
# ROUTECOST     :  41850
# DAY           :  D9
# CONSUMPTION   :  {('V4', 84, 'P4', 'D9', 0): 38567, ('V4', 84, 'P4', 'D9', 4): 0, ('V4', 84, 'P4', 'D9', 5): 0}
# CUSTOMER SET  :  ['C', 'D', 'G']
# TOTALDEMANDSER:  38567
# EACHCUSTOMERDE:  [0, 13081, 10637, 14849, 0]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  11
# PRODUCT TYPE  :  P4
# START REFINERY:  B
# END REFINERY  :  B
# ROUTE         :  ['B', 'G', 'B']
# ROUTECOST     :  22500
# DAY           :  D11
# CONSUMPTION   :  {('V4', 11, 'P4', 'D11', 0): 11365, ('V4', 11, 'P4', 'D11', 2): 0}
# CUSTOMER SET  :  ['G']
# TOTALDEMANDSER:  11365
# EACHCUSTOMERDE:  [0, 11365]
# **********************************************************
#
#
# **********************************************************
# VESSEL TYPE   :  V4
# ROUTE NO      :  19
# PRODUCT TYPE  :  P4
# START REFINERY:  A
# END REFINERY  :  A
# ROUTE         :  ['A', 'C', 'F', 'A']
# ROUTECOST     :  23850
# DAY           :  D11
# CONSUMPTION   :  {('V4', 19, 'P4', 'D11', 0): 26531, ('V4', 19, 'P4', 'D11', 3): 0}
# CUSTOMER SET  :  ['C', 'F']
# TOTALDEMANDSER:  26531
# EACHCUSTOMERDE:  [0, 12572, 13959]
# **********************************************************

# %%
total_routing_cost=0
for path in sol_paths:
    total_routing_cost+=path[1]['Cost']
vehicle_set_final_solution=[]
ct_refills=0
for k,v in sol_values.items():
    if v==1:
        if k[0] not in vehicle_set_final_solution:
            vehicle_set_final_solution.append(k[0])
        cur_consumption_list=list(feasible_path_dict[(k[0],k[2],k[3])][k[1]]['ConsumptionTracker'].values())
        if len(cur_consumption_list)>1:
            for x in range(1,len(cur_consumption_list)):
                if cur_consumption_list[x]>0:
                    ct_refills+=1

# %%
print("No. of Paths              : ",len(global_paths_set))
print("No  of Decision Variables : ", len(z))
print("No. of Routes Selected    : ",len(sol_paths))
print("Total Routing Cost        : ",total_routing_cost)
print("Demand Satisfied by Model : ",demand_satisfied_by_model)
print("Total Demand to be Sat    : ",total_demand_to_be_satisfied)
print("Vehicle Set               : ",vehicle_set_final_solution)
print("No of Refills             : ",ct_refills)
# Out:
# No. of Paths              :  126
# No  of Decision Variables :  39960
# No. of Routes Selected    :  47
# Total Routing Cost        :  1777050
# Demand Satisfied by Model :  2378990
# Total Demand to be Sat    :  3724991
# Vehicle Set               :  ['V4']
# No of Refills             :  0
